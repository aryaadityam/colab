# %% [markdown]
# # CapWords Colab Server
#
# Runtime: pilih GPU dulu di `Runtime > Change runtime type > T4 GPU`.
#
# Jangan buka `colab_server.py` sebagai notebook karena file `.py` bukan JSON notebook.

# %%
# !git clone https://github.com/aryaadityam/colab.git
# %cd colab

# %%
# !pip install -q -r requirements-colab.txt

# %%
NGROK_TOKEN = "PASTE_NGROK_TOKEN"
NGROK_DOMAIN = "squeak-barracuda-clench.ngrok-free.dev"
MODEL = "birefnet-general"

# !python colab_server.py \
  --model {MODEL} \
  --tunnel ngrok \
  --ngrok-token {NGROK_TOKEN} \
  --ngrok-domain {NGROK_DOMAIN}

# %% [markdown]
# Kalau `birefnet-general` terlalu berat/lama, ganti `MODEL` jadi `u2net` atau `birefnet-general-lite` lalu run ulang cell terakhir.
